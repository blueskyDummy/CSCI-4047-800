# %% [markdown]
# <p style="color: red; font-size: 24px;">Test code (importing modules)</p>

# %%
import pandas as pd, numpy, sklearn, seaborn, statsmodels, matplotlib
print("Environment ready")
# Out:
# Environment ready

# %% [markdown]
# <p style="color: red; font-size: 24px;">1. Loading in the data found in the **Income Data.csv** file</p>

# %%
df = pd.read_csv(r"C:\Users\sylar\Desktop\CSCI-4047-800\Mod02 Know Your Data\Income Data.csv")

# %% [markdown]
# <p style="color: red; font-size: 24px;">2. Printing that dataframe using `df.head()`</p>

# %%
df.head()
# Out:
#           job  type  income  education  prestige
# 0  accountant  prof      62         86        82
# 1       pilot  prof      72         76        83
# 2   architect  prof      75         92        90
# 3      author  prof      55         90        76
# 4     chemist  prof      64         86        90

# %% [markdown]
# <p style="color: red; font-size: 24px;">3. One thing i'm proud of yourself for this week, and my biggest phobia?
# </p>

# %% [markdown]
# Im proud of getting an early start on my classes and organizing my workflow.
# My biggest phobia is heights.
